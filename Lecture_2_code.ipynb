# %% [markdown]
# # String

# %%
a = 'me'
b = 'myself'
c = a + b
d = a + ' ' + b

# %%
d
# Out:
# 'me myself'

# %%
a
# Out:
# 'me'

# %%
a*3
# Out:
# 'mememe'

# %%
silly = a*3

# %%
silly
# Out:
# 'mememe'

# %%
s = 'abc'

# %%
len(s)
# Out:
# 3

# %% [markdown]
# # Indexing

# %%
s = 'abc'

# %%
s[0]
# Out:
# 'a'

# %%
s[1]
# Out:
# 'b'

# %%
s[2]
# Out:
# 'c'

# %%
s[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 s[3]
#
# IndexError: string index out of range

# %%
s[-1]
# Out:
# 'c'

# %%
s[-2]
# Out:
# 'b'

# %%
s[-3]
# Out:
# 'a'

# %% [markdown]
# # Slicing

# %%
s = 'abcdefgh'

# %%
s[3:6]
# Out:
# 'def'

# %%
s[3:6:2]
# Out:
# 'df'

# %%
s[:]
# Out:
# 'abcdefgh'

# %%
s[::-1]
# Out:
# 'hgfedcba'

# %%
s[4:1:-2]
# Out:
# 'ec'

# %% [markdown]
# # Manipulation

# %%
s = 'car'

# %%
s[0] = 'b'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 s[0] = 'b'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # we cant change a string after define it

# %%
s = 'b' + s[1:len(s)]

# %%
s
# Out:
# 'bar'

# %%
s[1:len(s)]
# Out:
# 'ar'

# %% [markdown]
# # Lecture

# %% [markdown]
# ### Printing

# %%
a ='the'

# %%
b = 3

# %%
c = 'musketeers'

# %%
print(a,b,c)
# Out:
# the 3 musketeers

# %%
print(a+b+c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 print(a+b+c)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(a + str(b) + c)
# Out:
# the3musketeers

# %%
num = 5
print('my num is', num)
# Out:
# my num is 5

# %%
s = 'my num is' + str(num)

# %%
s
# Out:
# 'my num is5'

# %%
print(s)
# Out:
# my num is5

# %%
x = 1

# %%
x_str = str(x)

# %%
print('my fevnumber is',x, '.', 'x=',x)
# Out:
# my fevnumber is 1 . x= 1

# %%
print('my number is' + x_str + 'x =' + x_str)
# Out:
# my number is1x =1

# %% [markdown]
# # User Input

# %%
# Example 1

# %%
text = input('Type anything')
print(text * 5)
# Out:
# Type anything usds
# usdsusdsusdsusdsusds

# %%
# Example 2

# %%
num1= input('Type a number')
print(num1 * 5)
# Out:
# Type a number 25
# 2525252525

# %%
num2 = int(input('Type a number'))
print(num2 * 5)
# Out:
# Type a number 5
# 25

# %%
# Write a program that: 
# * Asks the user for a verb.
# * Prints "I can _ better than you" where you replace _ with the verb.
# * Then prints the verb 5 times in a row separated by spaces.
# For example, if the user enters run, you print:
#     I can run better than you!
#     run run run run run

# %%
verb = input('Write verb')
print('I can '+ verb+ ' better than you')
print((verb + ' ') * 5)
# Out:
# Write verb run
# I can run better than you
# run run run run run

# %%
# Example 3 Newtons method for cube root

# %%
x = int(input('What x to find the root of cube root  ?'))
g = int(input('What guess to start with ?'))
print('Current estimated cubed = ', g**3)
next_g = g - ((g**3 - x)/(3*g**2))
print('Next guess to try = ', next_g)
# Out:
# What x to find the root of cube root  ? 2
# What guess to start with ? 4
# Current estimated cubed =  64
# Next guess to try =  2.708333333333333

# %% [markdown]
# # Fstring

# %%
num = 3000
fraction = 1/3
print(num*fraction, 'is', fraction*100, '% of', num)
print(num*fraction, 'is', str(fraction*100) + '% of ', num)
print(f'{num * fraction} ia {fraction * 100} % of {num}')
# Out:
# 1000.0 is 33.33333333333333 % of 3000
# 1000.0 is 33.33333333333333% of  3000
# 1000.0 ia 33.33333333333333 % of 3000

# %%
pset = 15
sleep_time = 8
print(sleep_time > pset)
derive = True
drink = False
both = drink and derive
print(both)
# Out:
# False
# False

# %%
############## YOU TRY IT ###############
# Write a program that:
# * Saves a secret number. 
# * Asks the user for a number guess.
# * Prints a bool depending on whether the guess matches the secret.

# %%
secret_num = int(input('Enter secret number'))
print(secret_num == 5)
# Out:
# Enter secret number 5
# True

# %% [markdown]
# # Branching

# %%
# Example  1

# %%
pset_time = 22
sleep_time = 8

if (pset_time + sleep_time) >  24:
    print('impossible')
elif(pset_time + sleep_time) >= 24:
    print('full schedule!')
else:
    leftover = abs(24 - pset_time - sleep_time)
    print(leftover)
print('end of day')
# Out:
# impossible
# end of day

# %%
abs(24 - 8 - 4)
# Out:
# 12

# %%
# # Buggy, fix it!
# x = int(input("Enter a number for x: "))
# y = int(input("Enter a different number for y: "))
# if x == y:
#     print(x,"is the same as",y)
# print("These are equal!")

# %%
x = int(input("Enter a number for x: "))
y = int(input("Enter a different number for y: "))
if x == y:
    print(x,"is the same as",y)
    print("These are equal!")
# Out:
# Enter a number for x:  1
# Enter a different number for y:  1
# 1 is the same as 1
# These are equal!

# %% [markdown]
# # Nested branching

# %%
# Example 1

# %%
x =  float(input('Enter a number for x: '))
y =  float(input('Enter a number for y: '))
if x == y:
    print('x and y are equal')
    if y != 0:
        print('therefore, x / y is ', x/y)
elif x < y:
    print('x is smaller')
else:
    print('y s smaller')
print('thanks')
# Out:
# Enter a number for x:  1
# Enter a number for y:  3
# x is smaller
# thanks

# %%
# What's printed when y = 2, y = 20, y = 11?
# What if "if x <= y:" becomes "elif x <= y:"

# %%
y = 2
y = 20
y = 22

# %%
y
# Out:
# 22

# %%
answer  = ''
x = 2
y = 11
if x == y:
    answer = answer + 'M'
elif x <= y:
    answer = answer + 'i'
else:
    answer = answer + 'T'
print(answer)
# Out:
# i

# %%
# Write a program that:
# * Saves a secret number. 
# * Asks the user for a number guess.
# * Prints whether the guess is too low, too high, or the same as the secret.

# %%
secret_num = int(input('Enter secret number'))
if secret_num > 5:
    print('too high')
elif secret_num < 5:
    print('too low')
else:
    print('Correct')
# Out:
# Enter secret number 7
# too high
